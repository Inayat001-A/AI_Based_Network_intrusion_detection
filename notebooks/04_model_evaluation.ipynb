# %% [markdown]
# # AI-Based Network Intrusion Detection System (NIDS)
# ## ?? Phase 4: Comprehensive Model Evaluation & False Alarm Minimization
#
# This notebook evaluates multi-class detection rates, False Positive Rate (FPR) on benign flows, and ROC-AUC / PR-AUC curves.

# %%
import os
import sys
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Add project root
sys.path.append(os.path.abspath('..'))
from src.evaluate import run_evaluation, calculate_false_positive_rate

sns.set_theme(style="whitegrid")
# %matplotlib inline

# %% [markdown]
# ### 1. Run Complete Cybersecurity Evaluation Suite

# %%
eval_results = run_evaluation()
print(f"Overall Accuracy: {eval_results['overall_accuracy']*100:.2f}%")
print(f"False Positive Rate (FPR): {eval_results['false_positive_rate']*100:.4f}%")
print(f"Inference Throughput: {eval_results['throughput_flows_per_sec']:,.1f} flows/sec")

# %% [markdown]
# ### 2. Breakdown by Attack Type

# %%
df_per_class = pd.DataFrame(eval_results['per_class_metrics']).T
df_per_class[['precision', 'recall', 'f1', 'support']]
