# %% [markdown]
# # AI-Based Network Intrusion Detection System (NIDS)
# ## ? Phase 5: Real-Time Inference Engine & Live Packet Stream Processor
#
# This notebook demonstrates bidirectional flow aggregation, on-the-fly feature extraction, sub-millisecond AI inference, and structured SOC security alerting.

# %%
import os
import sys
import json
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Add project root
sys.path.append(os.path.abspath('..'))
from src.predict import RealTimeNIDSPredictor
from src.live_sniffer import LivePacketSniffer

sns.set_theme(style="whitegrid")
# %matplotlib inline

# %% [markdown]
# ### 1. Initialize Real-Time NIDS Predictor

# %%
predictor = RealTimeNIDSPredictor()
sniffer = LivePacketSniffer(flow_callback=predictor.process_flow)

# %% [markdown]
# ### 2. Stream Simulated Network Traffic & Generate Real-Time Alerts

# %%
test_csv_path = '../data/processed/test.csv'
sniffer.simulate_traffic_stream(test_csv_path, max_flows=50, delay_sec=0.01)

# %% [markdown]
# ### 3. Review Generated SIEM / SOC Security Alert Log

# %%
alerts_df = pd.read_csv('../logs/alerts.csv') if os.path.exists('../logs/alerts.csv') else pd.DataFrame()
print(f"Total Attacks Intercepted: {len(alerts_df)}")
alerts_df.head(10)
